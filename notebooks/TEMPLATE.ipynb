# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from kret_studies import *
from kret_studies.notebook import *
from kret_studies.complex import *

logger = get_notebook_logger()
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/Columbia/RL-Project/.env.
# INFO:datasets:JAX version 0.7.2 available.

# %%
from waymo_agent import *

# %%
MAP_DIR = Path(os.environ.get("MAPS_DIR"))

# %%
envconfig = EnvConfig()
envconfig.map_dir = MAP_DIR

# %%
env = RideShareEnv(config=envconfig)

# %%
s, info = env.reset()

# %%
env.map_name
# Out:
# 'manhattan'

# %%
env.render()

# %%
env.vehicles
# Out:
# [VehicleState(node=366, battery=0.9749149036434438, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=366, travel_distance_total=0.0),
#  VehicleState(node=1881, battery=0.7428965162862669, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=1881, travel_distance_total=0.0),
#  VehicleState(node=1169, battery=0.7495443291611991, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=1169, travel_distance_total=0.0),
#  VehicleState(node=1985, battery=0.9309302507028818, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=1985, travel_distance_total=0.0)]
