# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from kret_studies import *
from kret_studies.notebook import *
from kret_studies.complex import *

logger = get_notebook_logger()
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/Columbia/RL-Project/.env.
# INFO:datasets:JAX version 0.7.2 available.

# %%
from waymo_agent import *

# %%
envconfig = EnvConfig()

# %%
env = RideShareEnv(config=envconfig)

# %%
s, info = env.reset()

# %%
env.map_name
# Out:
# 'manhattan-sparse-772-nodes-enriched.graphml'

# %%
# env.save_render(IMG_DIR / "manhattan-debug.png")

# %%
env.vehicles
# Out:
# [VehicleState(node=638, battery=0.6519931694498929, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=638, travel_distance_total=0.0),
#  VehicleState(node=52, battery=0.8967337196725329, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=52, travel_distance_total=0.0),
#  VehicleState(node=458, battery=0.70867920888274, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=458, travel_distance_total=0.0),
#  VehicleState(node=387, battery=0.9441064400381559, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=387, travel_distance_total=0.0),
#  VehicleState(node=745, battery=0.6992379531965569, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=745, travel_distance_total=0.0),
#  VehicleState(node=60, battery=0.864817743383612, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=60, travel_distance_total=0.0),
#  VehicleState(node=669, battery=0.6826301406674352, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=669, travel_distance_total=0.0),
#  VehicleState(node=547, battery=0.6362435783771518, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=547, travel_distance_total=0.0),
#  VehicleState(node=35, battery=0.7925178890770702, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=35, travel_distance_total=0.0),
#  VehicleState(node=389, battery=0.8752958605662025, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=389, travel_distance_total=0.0),
#  VehicleState(node=545, battery=0.6256936144987145, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=545, travel_distance_total=0.0),
#  VehicleState(node=383, battery=0.984335607000929, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=383, travel_distance_total=0.0),
#  VehicleState(node=210, battery=0.6798206666263293, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=210, travel_distance_total=0.0),
#  VehicleState(node=99, battery=0.9112022985868518, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=99, travel_distance_total=0.0),
#  VehicleState(node=393, battery=0.9345061965070585, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=393, travel_distance_total=0.0),
#  VehicleState(node=757, battery=0.8375095042484575, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=757, travel_distance_total=0.0),
#  VehicleState(node=459, battery=0.7924838797586639, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=459, travel_distance_total=0.0),
#  VehicleState(node=665, battery=0.8050642179360005, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=665, travel_distance_total=0.0),
#  VehicleState(node=760, battery=0.777836558063571, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=760, travel_distance_total=0.0),
#  VehicleState(node=630, battery=0.604454765832209, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=630, travel_distance_total=0.0),
#  VehicleState(node=708, battery=0.8979386185151623, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=708, travel_distance_total=0.0),
#  VehicleState(node=129, battery=0.7744787555276108, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=129, travel_distance_total=0.0),
#  VehicleState(node=296, battery=0.8659662459582229, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=296, travel_distance_total=0.0),
#  VehicleState(node=661, battery=0.8988251484210823, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=661, travel_distance_total=0.0),
#  VehicleState(node=543, battery=0.7736183008086555, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=543, travel_distance_total=0.0),
#  VehicleState(node=297, battery=0.629855771667821, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=297, travel_distance_total=0.0),
#  VehicleState(node=665, battery=0.8602671466924724, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=665, travel_distance_total=0.0),
#  VehicleState(node=475, battery=0.696934404132181, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=475, travel_distance_total=0.0),
#  VehicleState(node=577, battery=0.7149509019555225, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=577, travel_distance_total=0.0),
#  VehicleState(node=624, battery=0.9741790109729902, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=624, travel_distance_total=0.0),
#  VehicleState(node=758, battery=0.7253415002180565, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=758, travel_distance_total=0.0),
#  VehicleState(node=240, battery=0.8100168274183548, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=240, travel_distance_total=0.0),
#  VehicleState(node=335, battery=0.8955751539429779, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=335, travel_distance_total=0.0),
#  VehicleState(node=154, battery=0.813375600790348, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=154, travel_distance_total=0.0),
#  VehicleState(node=716, battery=0.8901409102656979, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=716, travel_distance_total=0.0),
#  VehicleState(node=720, battery=0.985132808677915, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=720, travel_distance_total=0.0),
#  VehicleState(node=702, battery=0.9203111664876755, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=702, travel_distance_total=0.0),
#  VehicleState(node=127, battery=0.9891801077367386, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=127, travel_distance_total=0.0),
#  VehicleState(node=441, battery=0.674263367466351, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=441, travel_distance_total=0.0),
#  VehicleState(node=453, battery=0.8433711717752863, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=453, travel_distance_total=0.0),
#  VehicleState(node=555, battery=0.7047884616444801, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=555, travel_distance_total=0.0),
#  VehicleState(node=456, battery=0.6341371095197231, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=456, travel_distance_total=0.0),
#  VehicleState(node=445, battery=0.7206055912823371, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=445, travel_distance_total=0.0),
#  VehicleState(node=398, battery=0.8120028497611546, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=398, travel_distance_total=0.0),
#  VehicleState(node=572, battery=0.8052647866287699, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=572, travel_distance_total=0.0),
#  VehicleState(node=654, battery=0.6059086628986128, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=654, travel_distance_total=0.0),
#  VehicleState(node=192, battery=0.7226154662601735, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=192, travel_distance_total=0.0),
#  VehicleState(node=334, battery=0.9647925958817299, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=334, travel_distance_total=0.0),
#  VehicleState(node=105, battery=0.9743000701166133, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=105, travel_distance_total=0.0),
#  VehicleState(node=457, battery=0.85400531206991, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=457, travel_distance_total=0.0),
#  VehicleState(node=622, battery=0.8495399341494391, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=622, travel_distance_total=0.0),
#  VehicleState(node=532, battery=0.9822462019749918, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=532, travel_distance_total=0.0),
#  VehicleState(node=611, battery=0.6803294711146811, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=611, travel_distance_total=0.0),
#  VehicleState(node=107, battery=0.9762903754429311, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=107, travel_distance_total=0.0),
#  VehicleState(node=577, battery=0.9146242748851416, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=577, travel_distance_total=0.0),
#  VehicleState(node=656, battery=0.7936766025098171, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=656, travel_distance_total=0.0),
#  VehicleState(node=427, battery=0.9794721324778808, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=427, travel_distance_total=0.0),
#  VehicleState(node=648, battery=0.7927890253985549, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=648, travel_distance_total=0.0),
#  VehicleState(node=550, battery=0.8257827229112616, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=550, travel_distance_total=0.0),
#  VehicleState(node=295, battery=0.6876893785059629, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=295, travel_distance_total=0.0),
#  VehicleState(node=436, battery=0.7933359547872666, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=436, travel_distance_total=0.0),
#  VehicleState(node=625, battery=0.9414643808100974, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=625, travel_distance_total=0.0),
#  VehicleState(node=549, battery=0.8893077481485728, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=549, travel_distance_total=0.0),
#  VehicleState(node=768, battery=0.9263909571708733, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=768, travel_distance_total=0.0),
#  VehicleState(node=351, battery=0.9606215808026322, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=351, travel_distance_total=0.0),
#  VehicleState(node=390, battery=0.967048748114361, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=390, travel_distance_total=0.0),
#  VehicleState(node=179, battery=0.763534329267601, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=179, travel_distance_total=0.0),
#  VehicleState(node=474, battery=0.9432293912160661, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=474, travel_distance_total=0.0),
#  VehicleState(node=393, battery=0.9995608097699182, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=393, travel_distance_total=0.0),
#  VehicleState(node=79, battery=0.7771048001757797, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=79, travel_distance_total=0.0),
#  VehicleState(node=674, battery=0.6409371750159667, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=674, travel_distance_total=0.0),
#  VehicleState(node=46, battery=0.9051356934496437, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=46, travel_distance_total=0.0),
#  VehicleState(node=404, battery=0.8085130506606218, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=404, travel_distance_total=0.0),
#  VehicleState(node=492, battery=0.961667505555695, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=492, travel_distance_total=0.0),
#  VehicleState(node=86, battery=0.8362459911480582, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=86, travel_distance_total=0.0),
#  VehicleState(node=424, battery=0.9462915719968892, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=424, travel_distance_total=0.0),
#  VehicleState(node=735, battery=0.8115560702962309, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=735, travel_distance_total=0.0),
#  VehicleState(node=655, battery=0.9712339312036823, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=655, travel_distance_total=0.0),
#  VehicleState(node=161, battery=0.9219643879588222, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=161, travel_distance_total=0.0),
#  VehicleState(node=461, battery=0.66465080456752, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=461, travel_distance_total=0.0),
#  VehicleState(node=511, battery=0.6770791526196448, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=511, travel_distance_total=0.0),
#  VehicleState(node=246, battery=0.9219346986543945, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=246, travel_distance_total=0.0),
#  VehicleState(node=137, battery=0.734126884178905, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=137, travel_distance_total=0.0),
#  VehicleState(node=124, battery=0.9158804392123698, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=124, travel_distance_total=0.0),
#  VehicleState(node=394, battery=0.6137031947043982, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=394, travel_distance_total=0.0),
#  VehicleState(node=736, battery=0.8711151329282689, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=736, travel_distance_total=0.0),
#  VehicleState(node=389, battery=0.6764515001904011, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=389, travel_distance_total=0.0),
#  VehicleState(node=90, battery=0.9222236446433792, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=90, travel_distance_total=0.0),
#  VehicleState(node=400, battery=0.7770565175195377, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=400, travel_distance_total=0.0),
#  VehicleState(node=451, battery=0.9555819011992297, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=451, travel_distance_total=0.0),
#  VehicleState(node=478, battery=0.6269201273668996, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=478, travel_distance_total=0.0),
#  VehicleState(node=588, battery=0.7903302703014397, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=588, travel_distance_total=0.0),
#  VehicleState(node=178, battery=0.8567003852045845, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=178, travel_distance_total=0.0),
#  VehicleState(node=315, battery=0.6183146543093799, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=315, travel_distance_total=0.0),
#  VehicleState(node=129, battery=0.9028426157229958, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=129, travel_distance_total=0.0),
#  VehicleState(node=63, battery=0.8171411705157405, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=63, travel_distance_total=0.0),
#  VehicleState(node=207, battery=0.7824327495731687, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=207, travel_distance_total=0.0),
#  VehicleState(node=635, battery=0.9569194351321588, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=635, travel_distance_total=0.0),
#  VehicleState(node=600, battery=0.8986706159314969, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=600, travel_distance_total=0.0),
#  VehicleState(node=674, battery=0.6117055175503877, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=674, travel_distance_total=0.0),
#  VehicleState(node=302, battery=0.6369531259882553, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=302, travel_distance_total=0.0),
#  VehicleState(node=201, battery=0.6978569801173469, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=201, travel_distance_total=0.0),
#  VehicleState(node=147, battery=0.7832813970564764, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=147, travel_distance_total=0.0),
#  VehicleState(node=584, battery=0.8945982372361464, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=584, travel_distance_total=0.0),
#  VehicleState(node=425, battery=0.8688576681145987, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=425, travel_distance_total=0.0),
#  VehicleState(node=25, battery=0.6681037872014851, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=25, travel_distance_total=0.0),
#  VehicleState(node=511, battery=0.6639234914017443, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=511, travel_distance_total=0.0),
#  VehicleState(node=171, battery=0.6988679610165056, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=171, travel_distance_total=0.0),
#  VehicleState(node=20, battery=0.6940973863106351, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=20, travel_distance_total=0.0),
#  VehicleState(node=36, battery=0.7574022965120862, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=36, travel_distance_total=0.0),
#  VehicleState(node=66, battery=0.6412400802023704, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=66, travel_distance_total=0.0),
#  VehicleState(node=684, battery=0.6458257937628382, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=684, travel_distance_total=0.0),
#  VehicleState(node=423, battery=0.6279855812182619, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=423, travel_distance_total=0.0),
#  VehicleState(node=486, battery=0.8223527735089675, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=486, travel_distance_total=0.0),
#  VehicleState(node=143, battery=0.6547364317302959, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=143, travel_distance_total=0.0),
#  VehicleState(node=101, battery=0.9644927311110234, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=101, travel_distance_total=0.0),
#  VehicleState(node=705, battery=0.8632957877601184, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=705, travel_distance_total=0.0),
#  VehicleState(node=333, battery=0.9551063199203053, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=333, travel_distance_total=0.0),
#  VehicleState(node=764, battery=0.9098460057291483, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=764, travel_distance_total=0.0),
#  VehicleState(node=762, battery=0.891306931959398, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=762, travel_distance_total=0.0),
#  VehicleState(node=664, battery=0.8968163387015646, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=664, travel_distance_total=0.0),
#  VehicleState(node=392, battery=0.7497954447823543, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=392, travel_distance_total=0.0),
#  VehicleState(node=411, battery=0.9363300959909161, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=411, travel_distance_total=0.0),
#  VehicleState(node=704, battery=0.7057571041351792, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=704, travel_distance_total=0.0),
#  VehicleState(node=482, battery=0.9236575773815123, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=482, travel_distance_total=0.0),
#  VehicleState(node=185, battery=0.8596354183062556, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=185, travel_distance_total=0.0),
#  VehicleState(node=436, battery=0.6816999114086947, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=436, travel_distance_total=0.0),
#  VehicleState(node=32, battery=0.7558076514105027, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=32, travel_distance_total=0.0),
#  VehicleState(node=688, battery=0.8525697835639492, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=688, travel_distance_total=0.0),
#  VehicleState(node=487, battery=0.6702202762892493, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=487, travel_distance_total=0.0),
#  VehicleState(node=584, battery=0.9245108443119885, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=584, travel_distance_total=0.0),
#  VehicleState(node=611, battery=0.8263072184542277, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=611, travel_distance_total=0.0),
#  VehicleState(node=585, battery=0.9959927819624894, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=585, travel_distance_total=0.0),
#  VehicleState(node=202, battery=0.6040565577648204, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=202, travel_distance_total=0.0),
#  VehicleState(node=160, battery=0.7994184664505515, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=160, travel_distance_total=0.0),
#  VehicleState(node=714, battery=0.7587364398538348, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=714, travel_distance_total=0.0),
#  VehicleState(node=241, battery=0.7701673405836931, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=241, travel_distance_total=0.0),
#  VehicleState(node=202, battery=0.9838211105190278, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=202, travel_distance_total=0.0),
#  VehicleState(node=256, battery=0.7243804352921115, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=256, travel_distance_total=0.0),
#  VehicleState(node=719, battery=0.6845192729207802, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=719, travel_distance_total=0.0),
#  VehicleState(node=409, battery=0.9264560180156511, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=409, travel_distance_total=0.0),
#  VehicleState(node=206, battery=0.8153431208091518, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=206, travel_distance_total=0.0),
#  VehicleState(node=425, battery=0.6777553244911826, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=425, travel_distance_total=0.0),
#  VehicleState(node=743, battery=0.9957027492838467, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=743, travel_distance_total=0.0),
#  VehicleState(node=575, battery=0.669512240849963, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=575, travel_distance_total=0.0),
#  VehicleState(node=386, battery=0.7673424095223341, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=386, travel_distance_total=0.0),
#  VehicleState(node=280, battery=0.7510684051204124, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=280, travel_distance_total=0.0),
#  VehicleState(node=380, battery=0.6625595676693514, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=380, travel_distance_total=0.0),
#  VehicleState(node=36, battery=0.9041236677281799, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=36, travel_distance_total=0.0),
#  VehicleState(node=673, battery=0.9417966416185353, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=673, travel_distance_total=0.0),
#  VehicleState(node=440, battery=0.9808636611216672, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=440, travel_distance_total=0.0),
#  VehicleState(node=142, battery=0.6561544584819827, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=142, travel_distance_total=0.0),
#  VehicleState(node=429, battery=0.8632480215643044, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=429, travel_distance_total=0.0),
#  VehicleState(node=732, battery=0.6884705403586917, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=732, travel_distance_total=0.0),
#  VehicleState(node=682, battery=0.7189048963192475, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=682, travel_distance_total=0.0),
#  VehicleState(node=561, battery=0.8071140379393081, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=561, travel_distance_total=0.0),
#  VehicleState(node=196, battery=0.6447663588824111, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=196, travel_distance_total=0.0),
#  VehicleState(node=562, battery=0.7954027662078758, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=562, travel_distance_total=0.0),
#  VehicleState(node=153, battery=0.7132445582538737, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=153, travel_distance_total=0.0),
#  VehicleState(node=418, battery=0.6550214022475059, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=418, travel_distance_total=0.0),
#  VehicleState(node=520, battery=0.7993401960596846, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=520, travel_distance_total=0.0),
#  VehicleState(node=364, battery=0.8937527069906032, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=364, travel_distance_total=0.0),
#  VehicleState(node=483, battery=0.6536894013337233, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=483, travel_distance_total=0.0),
#  VehicleState(node=608, battery=0.645900414904265, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=608, travel_distance_total=0.0),
#  VehicleState(node=307, battery=0.8097195793670204, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=307, travel_distance_total=0.0),
#  VehicleState(node=693, battery=0.7742868353807918, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=693, travel_distance_total=0.0),
#  VehicleState(node=727, battery=0.9688727854110777, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=727, travel_distance_total=0.0),
#  VehicleState(node=142, battery=0.8000512060748189, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=142, travel_distance_total=0.0),
#  VehicleState(node=214, battery=0.7989350611084426, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=214, travel_distance_total=0.0),
#  VehicleState(node=299, battery=0.7077339418146675, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=299, travel_distance_total=0.0),
#  VehicleState(node=466, battery=0.862661659222999, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=466, travel_distance_total=0.0),
#  VehicleState(node=366, battery=0.87376814524904, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=366, travel_distance_total=0.0),
#  VehicleState(node=228, battery=0.9384133523436741, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=228, travel_distance_total=0.0),
#  VehicleState(node=758, battery=0.6940600139764986, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=758, travel_distance_total=0.0),
#  VehicleState(node=380, battery=0.9692092834897342, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=380, travel_distance_total=0.0),
#  VehicleState(node=16, battery=0.6020142758009258, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=16, travel_distance_total=0.0),
#  VehicleState(node=472, battery=0.7446615985374617, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=472, travel_distance_total=0.0),
#  VehicleState(node=464, battery=0.6595664594361015, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=464, travel_distance_total=0.0),
#  VehicleState(node=153, battery=0.8744768858192363, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=153, travel_distance_total=0.0),
#  VehicleState(node=71, battery=0.7304302112621858, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=71, travel_distance_total=0.0),
#  VehicleState(node=134, battery=0.7608597043352984, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=134, travel_distance_total=0.0),
#  VehicleState(node=151, battery=0.9029884996353734, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=151, travel_distance_total=0.0),
#  VehicleState(node=557, battery=0.8016318337041461, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=557, travel_distance_total=0.0),
#  VehicleState(node=169, battery=0.9673530355217623, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=169, travel_distance_total=0.0),
#  VehicleState(node=355, battery=0.9584787443225496, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=355, travel_distance_total=0.0),
#  VehicleState(node=699, battery=0.7911860402543767, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=699, travel_distance_total=0.0),
#  VehicleState(node=160, battery=0.6941210255359187, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=160, travel_distance_total=0.0),
#  VehicleState(node=191, battery=0.6409931699028562, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=191, travel_distance_total=0.0),
#  VehicleState(node=733, battery=0.8373493685258068, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=733, travel_distance_total=0.0),
#  VehicleState(node=474, battery=0.8196912773745295, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=474, travel_distance_total=0.0),
#  VehicleState(node=379, battery=0.8018763152224914, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=379, travel_distance_total=0.0),
#  VehicleState(node=749, battery=0.8746193938315988, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=749, travel_distance_total=0.0),
#  VehicleState(node=178, battery=0.6700733547368863, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=178, travel_distance_total=0.0)]

# %%
env.render()
