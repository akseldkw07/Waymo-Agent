# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from kret_studies import *
from kret_studies.notebook import *
from kret_studies.complex import *

logger = get_notebook_logger()
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/Columbia/RL-Project/.env.
# INFO:datasets:JAX version 0.7.2 available.
# INFO:arviz.preview:arviz_base not installed
# INFO:arviz.preview:arviz_stats not installed
# INFO:arviz.preview:arviz_plots not installed
# /Users/Akseldkw/coding/kretsinger/data/nb_log.log

# %%
from waymo_agent import *

# %%
MAP_DIR = Path(os.environ.get("DATA_DIR")) / "maps"

# %%
envconfig = EnvConfig()
envconfig.map_dir = MAP_DIR

# %%
env = RideShareEnv(config=envconfig)

# %%
s, info = env.reset()

# %%
env.map_name
# Out:
# 'mini_grid'

# %%
env.render()
# Out:
# [2025-10-25 12:57:34] [WARNING] Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
env.vehicles
# Out:
# [VehicleState(node=2, battery=0.8717728248878631, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=2, travel_distance_total=0.0),
#  VehicleState(node=6, battery=0.7635586251809133, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=6, travel_distance_total=0.0),
#  VehicleState(node=7, battery=0.7074479895160511, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=7, travel_distance_total=0.0),
#  VehicleState(node=7, battery=0.7311471736034011, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=7, travel_distance_total=0.0),
#  VehicleState(node=5, battery=0.6802845803159102, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=5, travel_distance_total=0.0),
#  VehicleState(node=6, battery=0.7836049451800485, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=6, travel_distance_total=0.0),
#  VehicleState(node=6, battery=0.8168476712627358, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=6, travel_distance_total=0.0),
#  VehicleState(node=4, battery=0.8374746038906139, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=4, travel_distance_total=0.0),
#  VehicleState(node=7, battery=0.683701850490842, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=7, travel_distance_total=0.0),
#  VehicleState(node=0, battery=0.6084499884127091, status=<VehicleStatus.IDLE: 0>, target_node=None, remaining_distance=0.0, ride_id=None, origin_node=0, travel_distance_total=0.0)]
