# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from kret_studies import *
from kret_studies.notebook import *
from kret_studies.complex import *

logger = get_notebook_logger()
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/Columbia/RL-Project/.env.
# INFO:datasets:JAX version 0.7.2 available.

# %%
import itertools
import copy
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Grab edge list data hosted on Gist
edgelist = pd.read_csv(
    "https://gist.githubusercontent.com/brooksandrew/e570c38bcc72a8d102422f2af836513b/raw/89c76b2563dbc0e88384719a35cba0dfc04cd522/edgelist_sleeping_giant.csv"
)

# %%
# Grab node list data hosted on Gist
nodelist = pd.read_csv(
    "https://gist.githubusercontent.com/brooksandrew/f989e10af17fb4c85b11409fea47895b/raw/a3a8da0fa5b094f1ca9d82e1642b384889ae16e8/nodelist_sleeping_giant.csv"
)

# %%
# Create empty graph
g = nx.Graph()
# Add edges and edge attributes
for i, elrow in edgelist.iterrows():
    g.add_edge(elrow[0], elrow[1], attr_dict=elrow[2:].to_dict())
# Out:
# /var/folders/dj/k5kk5wk90vvcnb_wphpw490r0000gn/T/ipykernel_17061/3282189973.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   g.add_edge(elrow[0], elrow[1], attr_dict=elrow[2:].to_dict())

# %%
# Define node positions data structure (dict) for plotting
node_positions = {node[0]: (node[1]["X"], -node[1]["Y"]) for node in g.nodes(data=True)}

# Preview of node_positions with a bit of hack (there is no head/slice method for dictionaries).
dict(list(node_positions.items())[0:5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Define node positions data structure (dict) for plotting
# ----> 2 node_positions = {node[0]: (node[1]['X'], -node[1]['Y']) for node in g.nodes(data=True)}
#       4 # Preview of node_positions with a bit of hack (there is no head/slice method for dictionaries).
#       5 dict(list(node_positions.items())[0:5])
#
# KeyError: 'X'

# %%
# Define data structure (list) of edge colors for plotting
edge_colors = [e[2]["color"] for e in g.edges(data=True)]

# Preview first 10
edge_colors[0:10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Define data structure (list) of edge colors for plotting
# ----> 2 edge_colors = [e[2]['color'] for e in g.edges(data=True)]
#       4 # Preview first 10
#       5 edge_colors[0:10]
#
# KeyError: 'color'
